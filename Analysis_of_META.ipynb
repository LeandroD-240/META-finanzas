# %% [markdown]
# # Instituto Tecnológico de Las Américas (ITLA)
#
# ## Análisis de las acciones de META Inc.
#
# ### Analítica de datos para finanzas
#
# Sustentantes:
# - Leandro Díaz (2023-0006)
# - Laura Ramírez (2023-0132)
# - Jesús Araujo (2022-1894)
#
# **Prof.:** Gregory De La Rosa
#
# **Fecha:** *2/10/2024*

# %% [markdown]
# Índice: # Esto es para que se guien más que nada
# - Carga de datos
#     - Preprocesamiento
#     - Importación de datos
# - Análisis exploratorio de datos
#     - Estadísticos básicos
#     - Datos nulos y duplicados
# - Visualización de datos

# %% [markdown]
# # Carga de datos

# %% [markdown]
# ## Preprocesamiento

# %% [markdown]
# ## Importación de datos

# %%
# pip install yfinance

# %%
# Librerías
import yfinance as yf

# %%
# Carga de datos
df = yf.download('META', start='2021-01-01', end='2024-01-01')
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                       Adj Close       Close        High         Low  \
# Ticker                           META        META        META        META
# Date
# 2021-01-04 00:00:00+00:00  268.132690  268.940002  275.000000  265.200012
# 2021-01-05 00:00:00+00:00  270.156586  270.970001  272.399994  268.209991
# 2021-01-06 00:00:00+00:00  262.519592  263.309998  267.750000  260.010010
# 2021-01-07 00:00:00+00:00  267.933258  268.739990  271.609985  264.779999
# 2021-01-08 00:00:00+00:00  266.766785  267.570007  268.950012  263.179993
#
# Price                            Open    Volume
# Ticker                           META      META
# Date
# 2021-01-04 00:00:00+00:00  274.779999  15106100
# 2021-01-05 00:00:00+00:00  268.290009   9871600
# 2021-01-06 00:00:00+00:00  262.000000  24354100
# 2021-01-07 00:00:00+00:00  265.899994  15789800
# 2021-01-08 00:00:00+00:00  268.309998  18528300

# %%
# El dataframe tiene multiíndices, el de Ticker no se necesita
df.columns
# Out:
# MultiIndex([('Adj Close', 'META'),
#             (    'Close', 'META'),
#             (     'High', 'META'),
#             (      'Low', 'META'),
#             (     'Open', 'META'),
#             (   'Volume', 'META')],
#            names=['Price', 'Ticker'])

# %%
# Borrar índice ticker, datos listos
df = df.stack()
df = df.reset_index(level=1, drop=True)
df.head()
# Out:
# /tmp/ipykernel_2557/443727690.py:2: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   df = df.stack()
# Price                       Adj Close       Close        High         Low  \
# Date
# 2021-01-04 00:00:00+00:00  268.132690  268.940002  275.000000  265.200012
# 2021-01-05 00:00:00+00:00  270.156586  270.970001  272.399994  268.209991
# 2021-01-06 00:00:00+00:00  262.519592  263.309998  267.750000  260.010010
# 2021-01-07 00:00:00+00:00  267.933258  268.739990  271.609985  264.779999
# 2021-01-08 00:00:00+00:00  266.766785  267.570007  268.950012  263.179993
#
# Price                            Open    Volume
# Date
# 2021-01-04 00:00:00+00:00  274.779999  15106100
# 2021-01-05 00:00:00+00:00  268.290009   9871600
# 2021-01-06 00:00:00+00:00  262.000000  24354100
# 2021-01-07 00:00:00+00:00  265.899994  15789800
# 2021-01-08 00:00:00+00:00  268.309998  18528300

# %% [markdown]
# # Análisis exploratorio de datos

# %% [markdown]
# ## Tipos de datos correctos

# %% [markdown]
# ## Datos nulos y duplicados
